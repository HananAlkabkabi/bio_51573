# %% [markdown]
# ## Working with lists

# %%
# declare an empty string

bob = ""

# declare a list
beatles = []

# %% [markdown]
# ### What kind of variable is this?

# %%
print(type(bob))
print(type(beatles))
# Out:
# <class 'str'>
# <class 'list'>

# %% [markdown]
# ### Populate and print a list

# %%
beatles = ["John", "Paul", "George", "Ringo", "Stuart"]

#print the whole list
print(beatles)
# Out:
# ['John', 'Paul', 'George', 'Ringo', 'Stuart']

# %% [markdown]
# ### Calculate and print the length of a list

# %%
# calculate number of beatles
number_of_beatles= (len(beatles))

# print number of beatles
print(f"There are {number_of_beatles} number of the beatles")
# Out:
# There are 5 number of the beatles

# %% [markdown]
# ### Print an item in a list
#
#    _see PowerPoint slides_

# %%
print(beatles)

# print the first beatle
print(beatles[0])

# many ways of print the last Beatle
print(beatles[-1])
print(beatles[4])
print(beatles[4])

#print Gorge
print(beatles[2])
print(beatles[-3])
# Out:
# ['John', 'Paul', 'George', 'Ringo', 'Stuart']
# John
# Stuart
# Stuart
# Stuart

# %% [markdown]
# ### Remove an item from a list

# %%
# Remove the last item in the list (bye, Stuart)
stu= beatles.pop()
print(stu)
print(beatles)

# What happened to the Beatles?
# Out:
# Stuart
# ['John', 'Paul', 'George', 'Ringo']

# %% [markdown]
# ### Make a new list

# %%
# make a list called 'stones' with the Rolling Stones (Mick, Ron, and Keith)
stones = ['Mick', 'Ron', 'Keith']

# %% [markdown]
# ### Add two lists

# %%
# add two lists together
print (f"the two group spreatly: {}, {}.format (beatles, stones)")
# print our new list
supergroup = beatles + stones

print(f"{len(supergroup)}, number :{supergroup}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # add two lists together
# ----> 2 print ("the two group spreatly: {}, {}".format (beatles, stones))
#       3 # print our new list
#       4 supergroup = beatles + stones
#
# NameError: name 'stones' is not defined

# %% [markdown]
# ### Make some new lists

# %%
# start fresh with new groups
jackson5 = ['jackie', 'tito', 'jermaine', 'marlon', 'michael']
destiny  = ['beyonce', 'kelly', 'michelle']
top40    = ['taylorswift', 'postmalone']

# make a supergroup
jackson5.pop()

# %% [markdown]
# ### Growing a list with `extend()`

# %%
# print our lists
print("Jackson5:, jackson5")

# use extend() to add Destiny's Child to the Jackson 5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 # print our lists
# ----> 2 print("Jackson5", jackson5)
#       4 # use extend() to add Destiny's Child to the Jackson 5
#
# NameError: name 'jackson5' is not defined

# %%
# extend() modifies a list in place, it doesn't return a value (i.e., a new list)
jackson5.extend(destiny)


#jackson5 = jackson5 + destiny
print(f"Here's the extend jackson5; {jackson5}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 # extend() modifies a list in place, it doesn't return a value (i.e., a new list)
# ----> 2 jackson5.extend()
#       4 print(f"Here's the extend Jackson5: {jackson5}")
#
# NameError: name 'jackson5' is not defined

# %%
# use "+" if you want to create a new list

# %% [markdown]
# ### Growing a list with `append()`

# %%
# use `append()` to add some old men
num = [1, 2, 3]
let = ["a", "b", "c"]
print(f"our lists: {let, num}")
# What did append do?
num.append(let)
print(f"after appending let to num; {num}")

more_num = [4, 5, 6]
more_num.append(7)
i = 8
more_num.append(i)
print(more_num)
# Out:
# our lists: (['a', 'b', 'c'], [1, 2, 3])
# after appending let to num; [1, 2, 3, ['a', 'b', 'c']]
# [4, 5, 6, 7, 8]

# %%
# How long is this list?
print (len(num))

#print the letters 
print(num[-1])
print(num[3])
# Find and print Ringo, who is buried in there

#find and print b
#her's how to get the list
print(type(num[3]))
      
#
print(num[3][1])
# Out:
# 4
# ['a', 'b', 'c']

# %% [markdown]
# # strings as lists
# # string are just a list of chracters

# %%
name= "beyonce"
print(name(0), name[-1])

# %%
gene = "ATTGGCAGttccggaaGTTCTAA"

#etract 
print(f"the first exson: {gene[0:8]}")
print(gene[0:8])

#get the start codone (the first three chracter of the gene)
print(gene[0:3])

#stope codon
print(gene[-3:])

#get the
# Out:
# the first exson: ATTGGCAG
# ATTGGCAG
# ATT
# TAA

# %%
#split our gene 
gene_as_list = list(gene)
print(gene_as_list)
# Out:
# ['A', 'T', 'T', 'G', 'G', 'C', 'A', 'G', 't', 't', 'c', 'c', 'g', 'g', 'a', 'a', 'G', 'T', 'T', 'C', 'T', 'A', 'A']
