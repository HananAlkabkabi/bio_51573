# %% [markdown]
# ## understanding `append`

# %%
# start fresh with new groups
jackson5 = ['jackie', 'tito', 'jermaine', 'marlon', 'michael']
destiny  = ['beyonce', 'kelly', 'michelle']
top40    = ['taylorswift', 'postmalone']

#
super = []
super.append(destiny)
super.append(jackson5)
super.append(top40)
print(len(super))
print(super)
# Out:
# 3
# [['beyonce', 'kelly', 'michelle'], ['jackie', 'tito', 'jermaine', 'marlon', 'michael'], ['taylorswift', 'postmalone']]

# %% [markdown]
# ## looping over a list

# %%
# loop over 'destiny'
print(destiny)
for i in destiny:
    print(i)
# Out:
# ['beyonce', 'kelly', 'michelle']
# beyonce
# kelly
# michelle

# %% [markdown]
# ## executing a nested `for` loop

# %%
# loop over desitny, as 
for i in super[0]:
    print(i)
# loop over jicksion, as 
for i in super[1]:
    print(i)

# loop over 40, as 
for i in super[2]:
    print(i)
print("here's the nsested for loop:")
print()

# counters
band_num = 0
total_band_size= 0

# loop within a loop
for band in super:
    ##
    band_num += 1 ##

    number_num = 1

    for member in band:
    print(f"{member} is member {member_num} of band {band_num}")
    number_num +=1
    
print (f"there are {}")
# Out:
#   Cell In[19], line 26
#     print(f"{member} is member {member_num} of band {band_num}")
#     ^
# IndentationError: expected an indented block after 'for' statement on line 25

# %% [markdown]
# ### retrieve the index _and_ the value with `enumerate()`

# %%
# lots of flexibility with enumerate()
presidents = ["George Washington", "John Adams", "Thomas Jefferson", "James Madison", "James Monroe", "John Quincy Adams", "Andrew Jackson", "Martin Van Buren", "William Henry Harrison", "John Tyler", "James Knox Polk", "Zachary Taylor", "Millard Fillmore", "Franklin Pierce", "James Buchanan", "Abraham Lincoln", "Andrew Johnson", "Ulysses S. Grant", "Rutherford Birchard Hayes", "James Abram Garfield", "Chester Alan Arthur", "Grover Cleveland", "Benjamin Harrison", "Grover Cleveland", "William McKinley", "Theodore Roosevelt", "William Howard Taft", "Woodrow Wilson", "Warren Gamaliel Harding", "Calvin Coolidge", "Herbert Clark Hoover", "Franklin Delano Roosevelt", "Harry S. Truman", "Dwight David Eisenhower", "John Fitzgerald Kennedy", "Lyndon Baines Johnson", "Richard Milhous Nixon", "Gerald Rudolph Ford", "James Earl Carter Jr.", "Ronald Wilson Reagan", "George Herbert Walker Bush", "William Jefferson Clinton", "George Walker Bush", "Barack Hussein Obama", "Donald Trump", "Joe Biden"]

for num, name in enumerate (presidents):
    print(f"presidents nt number {num+1} was {name}")
# Out:
# presidents nt number 1 was George Washington
# presidents nt number 2 was John Adams
# presidents nt number 3 was Thomas Jefferson
# presidents nt number 4 was James Madison
# presidents nt number 5 was James Monroe
# presidents nt number 6 was John Quincy Adams
# presidents nt number 7 was Andrew Jackson
# presidents nt number 8 was Martin Van Buren
# presidents nt number 9 was William Henry Harrison
# presidents nt number 10 was John Tyler
# presidents nt number 11 was James Knox Polk
# presidents nt number 12 was Zachary Taylor
# presidents nt number 13 was Millard Fillmore
# presidents nt number 14 was Franklin Pierce
# presidents nt number 15 was James Buchanan
# presidents nt number 16 was Abraham Lincoln
# presidents nt number 17 was Andrew Johnson
# presidents nt number 18 was Ulysses S. Grant
# presidents nt number 19 was Rutherford Birchard Hayes
# presidents nt number 20 was James Abram Garfield
# presidents nt number 21 was Chester Alan Arthur
# presidents nt number 22 was Grover Cleveland
# presidents nt number 23 was Benjamin Harrison
# presidents nt number 24 was Grover Cleveland
# presidents nt number 25 was William McKinley
# presidents nt number 26 was Theodore Roosevelt
# presidents nt number 27 was William Howard Taft
# presidents nt number 28 was Woodrow Wilson
# presidents nt number 29 was Warren Gamaliel Harding
# presidents nt number 30 was Calvin Coolidge
# presidents nt number 31 was Herbert Clark Hoover
# presidents nt number 32 was Franklin Delano Roosevelt
# presidents nt number 33 was Harry S. Truman
# presidents nt number 34 was Dwight David Eisenhower
# presidents nt number 35 was John Fitzgerald Kennedy
# presidents nt number 36 was Lyndon Baines Johnson
# presidents nt number 37 was Richard Milhous Nixon
# presidents nt number 38 was Gerald Rudolph Ford
# presidents nt number 39 was James Earl Carter Jr.
# presidents nt number 40 was Ronald Wilson Reagan
# presidents nt number 41 was George Herbert Walker Bush
# presidents nt number 42 was William Jefferson Clinton
# presidents nt number 43 was George Walker Bush
# presidents nt number 44 was Barack Hussein Obama
# presidents nt number 45 was Donald Trump
# presidents nt number 46 was Joe Biden

# %% [markdown]
# ## loop over a string

# %%
today = "Wednesday"
voweles = "aeiou"
for letter in today:
    if letter not in voweles:
        print(letter, end="")
# Out:
# Wdnsdy
