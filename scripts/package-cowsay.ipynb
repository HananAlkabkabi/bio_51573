# %%
import cowsay

# %%
cowsay.char_names
# Out:
# ['beavis',
#  'cheese',
#  'cow',
#  'daemon',
#  'dragon',
#  'fox',
#  'ghostbusters',
#  'kitty',
#  'meow',
#  'miki',
#  'milk',
#  'octopus',
#  'pig',
#  'stegosaurus',
#  'stimpy',
#  'trex',
#  'turkey',
#  'turtle',
#  'tux']

# %%
cowsay.cow("I finally installed cowsay!")
# Out:
#   ___________________________
# | I finally installed cowsay! |
# ...
#                            \
#                             \
#                               ^__^
#                               (oo)\_______
#                               (__)\       )\/\
#                                   ||----w |
#                                   ||     ||
